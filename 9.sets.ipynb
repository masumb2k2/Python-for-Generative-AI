# %% [markdown]
# Sets

# %%
set1={1,2,3,4,5}
type(set1)
# Out:
# set

# %%
set1=set()
type(set1)
# Out:
# set

# %%
set1={1,2,3,4,5,2,5}
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set1.add(7)
set1
set1.add(7)
set1
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
set1.remove(4)
set1
# Out:
# {1, 2, 3, 5, 7}

# %%
remove=set1.pop()
print(remove)
set1
# Out:
# 1
# {2, 3, 5, 7}

# %%
set1.clear()
set1
# Out:
# set()

# %%
set1={1,2,3,4,5,2,5}
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set2={1,2,5,7,9}
set2
# Out:
# {1, 2, 5, 7, 9}

# %%
union=set1.union(set2)
print(union)
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
intersection=set1.intersection(set2)
print(intersection)
# Out:
# {1, 2, 5}

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set2
# Out:
# {1, 2, 5, 7, 9}

# %%
set1.intersection_update(set2)

# %%
set1
# Out:
# {1, 2, 5}

# %%
set2={1,2,5}
set1={1,2}

# %%
set1.issubset(set2)
# Out:
# True
