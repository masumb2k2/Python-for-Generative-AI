# %% [markdown]
# # Variable

# %% [markdown]
# ## Syntax and Semantics

# %%
# Python is case Sensitive 
name = "John" 
Name = "Doe"

# %%
print(name)
print(Name)
# Out:
# John
# Doe

# %%
### Indentation
if 5 < 2:
    print("Five is greater than two!")
    print("Hello, World!")

# %%
# Comments in Python
# This is a single-line comment 
name = "Alice"  # This is an single line comment
"""
This is a multi-line comment
spanning multiple lines.        
It can be used to provide detailed explanations
or documentation within the code.
"""
# Out:
# '\nThis is a multi-line comment\nspanning multiple lines.        \nIt can be used to provide detailed explanations\nor documentation within the code.\n'

# %%
# Line Continuation
total = 1 + 2 + 3 + \
        4 + 5 + 6
print(total)
# Out:
# 21

# %%
# multiple statement in sigle line
a=5;b=12;c=a+b;print(c)
# Out:
# 17

# %%
##Understand  Semnatics In Python
# variable assignment
x=10
name="Masum"
istrue=True

# %%
istrue
# Out:
# True

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
## Type inference in Python
y = 3.14
print(type(y))
y = "Hello, Python!"
print(type(y))
# Out:
# <class 'float'>
# <class 'str'>

# %%
# variable assignment
## Naming Conventions
## Variable names should be descriptive
## They must start with a letter or an '_' and contains letter,numbers and underscores
## variables names case sensitive

# %%
# A-Z a-z, _
var_1=10
_var=20
# var-Name =20
# @var=30
