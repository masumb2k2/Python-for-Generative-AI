# %% [markdown]
# # OOP Basics
# - class
# - object

# %%
# a class is a blueprint of creating object 
class Car:
    pass

# %%
audi=Car()
print(audi)

# %%
audi.window=4
print(audi.window)
# Out:
# 4

# %%
bmw=Car()
bmw.doors=2
print(bmw.doors)
# Out:
# 2

# %%
print(bmw.window)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(bmw.window)
#
# AttributeError: 'Car' object has no attribute 'window'

# %%
dir(bmw)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
# Instance varibale and Methods
class Dog:
    # Constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age

#object cration
dog1=Dog('dora',2)

# %%
print(dog1.age)
# Out:
# 2

# %%
dog2=Dog('buddy',4)
print(dog2.name)
# Out:
# buddy

# %%
# define a class with instance method
class Dog:
    # Constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def bark(self):
        print(f'{self.name} bark as ghew')

# %%
dog1=Dog("tommy",5)
dog1.bark()
# Out:
# tommy bark as ghew

# %%
dog2=Dog('buddy',4)
print(dog2.name)
dog2.bark()
# Out:
# buddy
# buddy bark as ghew

# %%
# Modeling a Bank Account
# Define class for bank Account
class BankAccount:
    # constructor
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
        
    # methods 
    def deposite(self,amount):
        self.balance+=amount
        print(f"{amount} has deposite and new balace is {self.balance}")
    def withdraw(self,amount):
        if amount>self.balance:
            print('Insufficient Balace')
        else:
            self.balance-=amount
            print(f"{amount} withdraw and new balace is{self.balance}")
    def getBalace(self):
        return self.balance

# %%
# creating bank account (object)
user1=BankAccount('Puja',5000)
print(user1.balance)
# Out:
# 5000

# %%
user1.deposite(1000)
# Out:
# 1000 has deposite and new balace is 6000

# %%
user1.getBalace()
# Out:
# 6000

# %%
user1.withdraw(2000)
# Out:
# 2000 withdraw and new balace is4000
